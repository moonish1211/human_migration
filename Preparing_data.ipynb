# %% [markdown]
# # Preparind Subset of the data to different csv file

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
## Reading in data
big_data = pd.read_csv('data/Global_Human_Migration.csv')

##Since you are on Mac, the directory may be different, correct the code if it's wrong
# big_data = pd.read_csv('data\Global_Human_Migration.csv')

# %%
big_data.columns = ['Origin_name', 'Origin_code', 'Gender_Name', 'Gender_Code', 'Destination_name', "Destination_code", '1960', '1970', '1980', '1990', '2000']
big_data = big_data.drop('Gender_Name', axis=1)

# %% [markdown]
# ## Dataset by both gender, divided by decade

# %%
both_gender_df = big_data[big_data['Gender_Code'] == "TOT"]
both_gender_df.to_csv('data/both_gender.csv', index=False)
both_gender_df
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 462     Afghanistan         AFG         TOT         Afghanistan
# 463     Afghanistan         AFG         TOT             Albania
# 464     Afghanistan         AFG         TOT             Algeria
# 465     Afghanistan         AFG         TOT      American Samoa
# 466     Afghanistan         AFG         TOT             Andorra
# ...             ...         ...         ...                 ...
# 160771     Zimbabwe         ZWE         TOT   Wallis and Futuna
# 160772     Zimbabwe         ZWE         TOT  West Bank and Gaza
# 160773     Zimbabwe         ZWE         TOT         Yemen, Rep.
# 160774     Zimbabwe         ZWE         TOT              Zambia
# 160775     Zimbabwe         ZWE         TOT            Zimbabwe
#
#        Destination_code   1960   1970   1980   1990   2000
# 462                 AFG      0      0      0      0      0
# 463                 ALB      0      0      0      0      0
# ...

# %%
bothgen_1960 = both_gender_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1960"]]
bothgen_1960.to_csv('data/both_gender/1960.csv', index=False)
bothgen_1960
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 462     Afghanistan         AFG         TOT         Afghanistan
# 463     Afghanistan         AFG         TOT             Albania
# 464     Afghanistan         AFG         TOT             Algeria
# 465     Afghanistan         AFG         TOT      American Samoa
# 466     Afghanistan         AFG         TOT             Andorra
# ...             ...         ...         ...                 ...
# 160771     Zimbabwe         ZWE         TOT   Wallis and Futuna
# 160772     Zimbabwe         ZWE         TOT  West Bank and Gaza
# 160773     Zimbabwe         ZWE         TOT         Yemen, Rep.
# 160774     Zimbabwe         ZWE         TOT              Zambia
# 160775     Zimbabwe         ZWE         TOT            Zimbabwe
#
#        Destination_code   1960
# 462                 AFG      0
# 463                 ALB      0
# 464                 DZA     41
# 465                 ASM      0
# 466                 AND      0
# ...

# %%
bothgen_1970 = both_gender_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1970"]]
bothgen_1970.to_csv('data/both_gender/1970.csv', index=False)
bothgen_1970
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 462     Afghanistan         AFG         TOT         Afghanistan
# 463     Afghanistan         AFG         TOT             Albania
# 464     Afghanistan         AFG         TOT             Algeria
# 465     Afghanistan         AFG         TOT      American Samoa
# 466     Afghanistan         AFG         TOT             Andorra
# ...             ...         ...         ...                 ...
# 160771     Zimbabwe         ZWE         TOT   Wallis and Futuna
# 160772     Zimbabwe         ZWE         TOT  West Bank and Gaza
# 160773     Zimbabwe         ZWE         TOT         Yemen, Rep.
# 160774     Zimbabwe         ZWE         TOT              Zambia
# 160775     Zimbabwe         ZWE         TOT            Zimbabwe
#
#        Destination_code   1970
# 462                 AFG      0
# 463                 ALB      0
# 464                 DZA     16
# 465                 ASM      0
# 466                 AND      0
# ...

# %%
bothgen_1980 = both_gender_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1980"]]
bothgen_1980.to_csv('data/both_gender/1980.csv', index=False)
bothgen_1980
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 462     Afghanistan         AFG         TOT         Afghanistan
# 463     Afghanistan         AFG         TOT             Albania
# 464     Afghanistan         AFG         TOT             Algeria
# 465     Afghanistan         AFG         TOT      American Samoa
# 466     Afghanistan         AFG         TOT             Andorra
# ...             ...         ...         ...                 ...
# 160771     Zimbabwe         ZWE         TOT   Wallis and Futuna
# 160772     Zimbabwe         ZWE         TOT  West Bank and Gaza
# 160773     Zimbabwe         ZWE         TOT         Yemen, Rep.
# 160774     Zimbabwe         ZWE         TOT              Zambia
# 160775     Zimbabwe         ZWE         TOT            Zimbabwe
#
#        Destination_code   1980
# 462                 AFG      0
# 463                 ALB      0
# 464                 DZA     13
# 465                 ASM      0
# 466                 AND      2
# ...

# %%
bothgen_1990 = both_gender_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1990"]]
bothgen_1990.to_csv('data/both_gender/1990.csv', index=False)
bothgen_1990
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 462     Afghanistan         AFG         TOT         Afghanistan
# 463     Afghanistan         AFG         TOT             Albania
# 464     Afghanistan         AFG         TOT             Algeria
# 465     Afghanistan         AFG         TOT      American Samoa
# 466     Afghanistan         AFG         TOT             Andorra
# ...             ...         ...         ...                 ...
# 160771     Zimbabwe         ZWE         TOT   Wallis and Futuna
# 160772     Zimbabwe         ZWE         TOT  West Bank and Gaza
# 160773     Zimbabwe         ZWE         TOT         Yemen, Rep.
# 160774     Zimbabwe         ZWE         TOT              Zambia
# 160775     Zimbabwe         ZWE         TOT            Zimbabwe
#
#        Destination_code   1990
# 462                 AFG      0
# 463                 ALB      0
# 464                 DZA     10
# 465                 ASM      0
# 466                 AND      5
# ...

# %%
bothgen_2000 = both_gender_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"2000"]]
bothgen_2000.to_csv('data/both_gender/2000.csv', index=False)
bothgen_2000
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 462     Afghanistan         AFG         TOT         Afghanistan
# 463     Afghanistan         AFG         TOT             Albania
# 464     Afghanistan         AFG         TOT             Algeria
# 465     Afghanistan         AFG         TOT      American Samoa
# 466     Afghanistan         AFG         TOT             Andorra
# ...             ...         ...         ...                 ...
# 160771     Zimbabwe         ZWE         TOT   Wallis and Futuna
# 160772     Zimbabwe         ZWE         TOT  West Bank and Gaza
# 160773     Zimbabwe         ZWE         TOT         Yemen, Rep.
# 160774     Zimbabwe         ZWE         TOT              Zambia
# 160775     Zimbabwe         ZWE         TOT            Zimbabwe
#
#        Destination_code   2000
# 462                 AFG      0
# 463                 ALB      0
# 464                 DZA      8
# 465                 ASM      0
# 466                 AND      6
# ...

# %% [markdown]
# ## Dataset by Woman, divided by decade

# %%
female_df = big_data[big_data['Gender_Code'] == "FEM"]
female_df.to_csv('data/female.csv', index=False)
female_df
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 0       Afghanistan         AFG         FEM         Afghanistan
# 1       Afghanistan         AFG         FEM             Albania
# 2       Afghanistan         AFG         FEM             Algeria
# 3       Afghanistan         AFG         FEM      American Samoa
# 4       Afghanistan         AFG         FEM             Andorra
# ...             ...         ...         ...                 ...
# 160309     Zimbabwe         ZWE         FEM   Wallis and Futuna
# 160310     Zimbabwe         ZWE         FEM  West Bank and Gaza
# 160311     Zimbabwe         ZWE         FEM         Yemen, Rep.
# 160312     Zimbabwe         ZWE         FEM              Zambia
# 160313     Zimbabwe         ZWE         FEM            Zimbabwe
#
#        Destination_code   1960   1970   1980   1990   2000
# 0                   AFG      0      0      0      0      0
# 1                   ALB      0      0      0      0      0
# ...

# %%
fem_1960 = female_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1960"]]
fem_1960.to_csv('data/female/1960.csv', index=False)
fem_1960
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 0       Afghanistan         AFG         FEM         Afghanistan
# 1       Afghanistan         AFG         FEM             Albania
# 2       Afghanistan         AFG         FEM             Algeria
# 3       Afghanistan         AFG         FEM      American Samoa
# 4       Afghanistan         AFG         FEM             Andorra
# ...             ...         ...         ...                 ...
# 160309     Zimbabwe         ZWE         FEM   Wallis and Futuna
# 160310     Zimbabwe         ZWE         FEM  West Bank and Gaza
# 160311     Zimbabwe         ZWE         FEM         Yemen, Rep.
# 160312     Zimbabwe         ZWE         FEM              Zambia
# 160313     Zimbabwe         ZWE         FEM            Zimbabwe
#
#        Destination_code   1960
# 0                   AFG      0
# 1                   ALB      0
# 2                   DZA     22
# 3                   ASM      0
# 4                   AND      0
# ...

# %%
fem_1970 = female_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1970"]]
fem_1970.to_csv('data/female/1970.csv', index=False)
fem_1970
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 0       Afghanistan         AFG         FEM         Afghanistan
# 1       Afghanistan         AFG         FEM             Albania
# 2       Afghanistan         AFG         FEM             Algeria
# 3       Afghanistan         AFG         FEM      American Samoa
# 4       Afghanistan         AFG         FEM             Andorra
# ...             ...         ...         ...                 ...
# 160309     Zimbabwe         ZWE         FEM   Wallis and Futuna
# 160310     Zimbabwe         ZWE         FEM  West Bank and Gaza
# 160311     Zimbabwe         ZWE         FEM         Yemen, Rep.
# 160312     Zimbabwe         ZWE         FEM              Zambia
# 160313     Zimbabwe         ZWE         FEM            Zimbabwe
#
#        Destination_code   1970
# 0                   AFG      0
# 1                   ALB      0
# 2                   DZA      8
# 3                   ASM      0
# 4                   AND      0
# ...

# %%
fem_1980 = female_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1980"]]
fem_1980.to_csv('data/female/1980.csv', index=False)
fem_1980
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 0       Afghanistan         AFG         FEM         Afghanistan
# 1       Afghanistan         AFG         FEM             Albania
# 2       Afghanistan         AFG         FEM             Algeria
# 3       Afghanistan         AFG         FEM      American Samoa
# 4       Afghanistan         AFG         FEM             Andorra
# ...             ...         ...         ...                 ...
# 160309     Zimbabwe         ZWE         FEM   Wallis and Futuna
# 160310     Zimbabwe         ZWE         FEM  West Bank and Gaza
# 160311     Zimbabwe         ZWE         FEM         Yemen, Rep.
# 160312     Zimbabwe         ZWE         FEM              Zambia
# 160313     Zimbabwe         ZWE         FEM            Zimbabwe
#
#        Destination_code   1980
# 0                   AFG      0
# 1                   ALB      0
# 2                   DZA      6
# 3                   ASM      0
# 4                   AND      0
# ...

# %%
fem_1990 = female_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1990"]]
fem_1990.to_csv('data/female/1990.csv', index=False)
fem_1990
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 0       Afghanistan         AFG         FEM         Afghanistan
# 1       Afghanistan         AFG         FEM             Albania
# 2       Afghanistan         AFG         FEM             Algeria
# 3       Afghanistan         AFG         FEM      American Samoa
# 4       Afghanistan         AFG         FEM             Andorra
# ...             ...         ...         ...                 ...
# 160309     Zimbabwe         ZWE         FEM   Wallis and Futuna
# 160310     Zimbabwe         ZWE         FEM  West Bank and Gaza
# 160311     Zimbabwe         ZWE         FEM         Yemen, Rep.
# 160312     Zimbabwe         ZWE         FEM              Zambia
# 160313     Zimbabwe         ZWE         FEM            Zimbabwe
#
#        Destination_code   1990
# 0                   AFG      0
# 1                   ALB      0
# 2                   DZA      5
# 3                   ASM      0
# 4                   AND      2
# ...

# %%
fem_2000 = female_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"2000"]]
fem_2000.to_csv('data/female/2000.csv', index=False)
fem_2000
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 0       Afghanistan         AFG         FEM         Afghanistan
# 1       Afghanistan         AFG         FEM             Albania
# 2       Afghanistan         AFG         FEM             Algeria
# 3       Afghanistan         AFG         FEM      American Samoa
# 4       Afghanistan         AFG         FEM             Andorra
# ...             ...         ...         ...                 ...
# 160309     Zimbabwe         ZWE         FEM   Wallis and Futuna
# 160310     Zimbabwe         ZWE         FEM  West Bank and Gaza
# 160311     Zimbabwe         ZWE         FEM         Yemen, Rep.
# 160312     Zimbabwe         ZWE         FEM              Zambia
# 160313     Zimbabwe         ZWE         FEM            Zimbabwe
#
#        Destination_code   2000
# 0                   AFG      0
# 1                   ALB      0
# 2                   DZA      4
# 3                   ASM      0
# 4                   AND      3
# ...

# %% [markdown]
# ## Dataset by Men, divided by decade

# %%
male_df = big_data[big_data['Gender_Code'] == "MAL"]
male_df.to_csv('data/male.csv', index=False)
male_df
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 231     Afghanistan         AFG         MAL         Afghanistan
# 232     Afghanistan         AFG         MAL             Albania
# 233     Afghanistan         AFG         MAL             Algeria
# 234     Afghanistan         AFG         MAL      American Samoa
# 235     Afghanistan         AFG         MAL             Andorra
# ...             ...         ...         ...                 ...
# 160540     Zimbabwe         ZWE         MAL   Wallis and Futuna
# 160541     Zimbabwe         ZWE         MAL  West Bank and Gaza
# 160542     Zimbabwe         ZWE         MAL         Yemen, Rep.
# 160543     Zimbabwe         ZWE         MAL              Zambia
# 160544     Zimbabwe         ZWE         MAL            Zimbabwe
#
#        Destination_code   1960   1970   1980   1990   2000
# 231                 AFG      0      0      0      0      0
# 232                 ALB      0      0      0      0      0
# ...

# %%
male_1960 = male_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1960"]]
male_1960.to_csv('data/male/1960.csv', index=False)
male_1960
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 231     Afghanistan         AFG         MAL         Afghanistan
# 232     Afghanistan         AFG         MAL             Albania
# 233     Afghanistan         AFG         MAL             Algeria
# 234     Afghanistan         AFG         MAL      American Samoa
# 235     Afghanistan         AFG         MAL             Andorra
# ...             ...         ...         ...                 ...
# 160540     Zimbabwe         ZWE         MAL   Wallis and Futuna
# 160541     Zimbabwe         ZWE         MAL  West Bank and Gaza
# 160542     Zimbabwe         ZWE         MAL         Yemen, Rep.
# 160543     Zimbabwe         ZWE         MAL              Zambia
# 160544     Zimbabwe         ZWE         MAL            Zimbabwe
#
#        Destination_code   1960
# 231                 AFG      0
# 232                 ALB      0
# 233                 DZA     19
# 234                 ASM      0
# 235                 AND      0
# ...

# %%
male_1970 = male_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1970"]]
male_1970.to_csv('data/male/1970.csv', index=False)
male_1970
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 231     Afghanistan         AFG         MAL         Afghanistan
# 232     Afghanistan         AFG         MAL             Albania
# 233     Afghanistan         AFG         MAL             Algeria
# 234     Afghanistan         AFG         MAL      American Samoa
# 235     Afghanistan         AFG         MAL             Andorra
# ...             ...         ...         ...                 ...
# 160540     Zimbabwe         ZWE         MAL   Wallis and Futuna
# 160541     Zimbabwe         ZWE         MAL  West Bank and Gaza
# 160542     Zimbabwe         ZWE         MAL         Yemen, Rep.
# 160543     Zimbabwe         ZWE         MAL              Zambia
# 160544     Zimbabwe         ZWE         MAL            Zimbabwe
#
#        Destination_code   1970
# 231                 AFG      0
# 232                 ALB      0
# 233                 DZA      8
# 234                 ASM      0
# 235                 AND      0
# ...

# %%
male_1980 = male_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1980"]]
male_1980.to_csv('data/male/1980.csv', index=False)
male_1980
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 231     Afghanistan         AFG         MAL         Afghanistan
# 232     Afghanistan         AFG         MAL             Albania
# 233     Afghanistan         AFG         MAL             Algeria
# 234     Afghanistan         AFG         MAL      American Samoa
# 235     Afghanistan         AFG         MAL             Andorra
# ...             ...         ...         ...                 ...
# 160540     Zimbabwe         ZWE         MAL   Wallis and Futuna
# 160541     Zimbabwe         ZWE         MAL  West Bank and Gaza
# 160542     Zimbabwe         ZWE         MAL         Yemen, Rep.
# 160543     Zimbabwe         ZWE         MAL              Zambia
# 160544     Zimbabwe         ZWE         MAL            Zimbabwe
#
#        Destination_code   1980
# 231                 AFG      0
# 232                 ALB      0
# 233                 DZA      6
# 234                 ASM      0
# 235                 AND      1
# ...

# %%
male_1990 = male_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"1990"]]
male_1990.to_csv('data/male/1990.csv', index=False)
male_1990
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 231     Afghanistan         AFG         MAL         Afghanistan
# 232     Afghanistan         AFG         MAL             Albania
# 233     Afghanistan         AFG         MAL             Algeria
# 234     Afghanistan         AFG         MAL      American Samoa
# 235     Afghanistan         AFG         MAL             Andorra
# ...             ...         ...         ...                 ...
# 160540     Zimbabwe         ZWE         MAL   Wallis and Futuna
# 160541     Zimbabwe         ZWE         MAL  West Bank and Gaza
# 160542     Zimbabwe         ZWE         MAL         Yemen, Rep.
# 160543     Zimbabwe         ZWE         MAL              Zambia
# 160544     Zimbabwe         ZWE         MAL            Zimbabwe
#
#        Destination_code   1990
# 231                 AFG      0
# 232                 ALB      0
# 233                 DZA      5
# 234                 ASM      0
# 235                 AND      3
# ...

# %%
male_2000 = male_df[["Origin_name",	"Origin_code",	"Gender_Code",	"Destination_name",	"Destination_code",	"2000"]]
male_2000.to_csv('data/male/2000.csv', index=False)
male_2000
# Out:
#         Origin_name Origin_code Gender_Code    Destination_name  \
# 231     Afghanistan         AFG         MAL         Afghanistan
# 232     Afghanistan         AFG         MAL             Albania
# 233     Afghanistan         AFG         MAL             Algeria
# 234     Afghanistan         AFG         MAL      American Samoa
# 235     Afghanistan         AFG         MAL             Andorra
# ...             ...         ...         ...                 ...
# 160540     Zimbabwe         ZWE         MAL   Wallis and Futuna
# 160541     Zimbabwe         ZWE         MAL  West Bank and Gaza
# 160542     Zimbabwe         ZWE         MAL         Yemen, Rep.
# 160543     Zimbabwe         ZWE         MAL              Zambia
# 160544     Zimbabwe         ZWE         MAL            Zimbabwe
#
#        Destination_code   2000
# 231                 AFG      0
# 232                 ALB      0
# 233                 DZA      4
# 234                 ASM      0
# 235                 AND      3
# ...
